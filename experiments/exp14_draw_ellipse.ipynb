# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("shinchan.jpg")

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

cv2.ellipse(img, (200, 200), (100, 50), 0, 0, 360, (255, 0, 0), 3)

plt.imshow(img)
plt.title("Ellipse")
plt.axis('off')
plt.show()
